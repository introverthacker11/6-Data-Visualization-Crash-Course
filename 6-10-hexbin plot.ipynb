# %% [markdown]
# ###
# ## hexbin plot
# ###

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

a = sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
a.plot.hexbin( x = 'sepal_width', y = 'sepal_length', C = 'petal_length', gridsize = 10, cmap = 'viridis')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# ###
# ## hexbin plot for only setosa species
# ###

# %%
import matplotlib.pyplot as plt
import seaborn as sns

a = sns.load_dataset('iris')
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
a[a['species'] == 'setosa'].plot.hexbin( x = 'sepal_width', y = 'sepal_length', C = 'petal_width', gridsize = 10, cmap = 'viridis')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>
